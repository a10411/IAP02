# %%
import pandas as pd
import numpy as np


df = pd.read_csv('grad-students.csv')

df['Grad_employment_rate'] = 1 - df['Grad_unemployment_rate']
df['Nongrad_employment_rate'] = 1 - df['Nongrad_unemployment_rate']
df.to_csv('grad-students-new-field.csv', index=False)
df
# Out:
#      index  Major_code                                       Major  \
# 0        0        5601                       CONSTRUCTION SERVICES
# 1        1        6004           COMMERCIAL ART AND GRAPHIC DESIGN
# 2        2        6211                      HOSPITALITY MANAGEMENT
# 3        3        2201      COSMETOLOGY SERVICES AND CULINARY ARTS
# 4        4        2001                  COMMUNICATION TECHNOLOGIES
# ..     ...         ...                                         ...
# 168    168        5203                       COUNSELING PSYCHOLOGY
# 169    169        5202                         CLINICAL PSYCHOLOGY
# 170    170        6106     HEALTH AND MEDICAL PREPARATORY PROGRAMS
# 171    171        2303                   SCHOOL STUDENT COUNSELING
# 172    172        2301  EDUCATIONAL ADMINISTRATION AND SUPERVISION
#
#                           Major_category  Grad_total  Grad_sample_size  \
# 0    Industrial Arts & Consumer Services        9173               200
# ...
